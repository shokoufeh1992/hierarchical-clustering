# %% [markdown]
# ## Import the relevant libraries

# %%
import numpy as np

import pandas as pd

import seaborn as sns

# %% [markdown]
# ## Load the data

# %%
data = pd.read_csv('Country clusters standardized.csv', index_col='Country')
data.head()
# Out:
#          Latitude  Longitude  Language
# Country
# USA      0.186540  -1.089160         0
# Canada   0.728588  -1.008604         0
# France   0.241895   0.137900         1
# UK       0.467671   0.080922         0
# Germany  0.378729   0.230360         2

# %%
x_scaled = data.copy()

x_scaled = x_scaled.drop(['Language'],axis=1)

x_scaled
# Out:
#            Latitude  Longitude
# Country
# USA        0.186540  -1.089160
# Canada     0.728588  -1.008604
# France     0.241895   0.137900
# UK         0.467671   0.080922
# Germany    0.378729   0.230360
# Australia -2.003422   1.648581

# %% [markdown]
# ## Plot the data

# %% [markdown]
# See the following address for a complete documentation:
#
# https://seaborn.pydata.org/generated/seaborn.clustermap.html

# %%
sns.clustermap(x_scaled, cmap='vlag')

# %% [markdown]
# ![000278.png](attachment:000278.png)

# %% [markdown]
# ![000279.png](attachment:000279.png)

# %%
data2 = pd.read_csv('Mall_Customers.csv', index_col='Age')
data2= data2.drop(['CustomerID','Gender'],axis=1)
data2
# Out:
#      Annual Income (k$)  Spending Score (1-100)
# Age
# 19                   15                      39
# 21                   15                      81
# 20                   16                       6
# 23                   16                      77
# 31                   17                      40
# ..                  ...                     ...
# 35                  120                      79
# 45                  126                      28
# 32                  126                      74
# 32                  137                      18
# 30                  137                      83
#
# [200 rows x 2 columns]

# %%
sns.clustermap(data2, cmap="vlag")
